# %%
# !dir
# Out:
# Pandas_Wprowadzenie.ipynb  RegularSeasonCompactResults.csv

# %%
pip install pandas
# Out:
# ...
#     100% |████████████████████████████████| 10.4MB 131kB/s ta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/62/20/4d43e141b5bc426ba38274933ef8e76e85c7adea2c321ecf9ebf7421cedf/numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ### Odczyt i zapis

# %%
df = pd.read_csv("RegularSeasonCompactResults.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0
# 5    1985      25   1218      79   1337      78    H      0
# 6    1985      25   1228      64   1226      44    N      0
# 7    1985      25   1242      58   1268      56    N      0
# 8    1985      25   1260      98   1133      80    H      0
# 9    1985      25   1305      97   1424      89    H      0

# %%
df.tail(10)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145279    2016     131   1392      80   1436      74    H      0
# 145280    2016     131   1401      71   1261      38    N      0
# 145281    2016     131   1419      82   1426      71    N      0
# 145282    2016     131   1433      76   1172      54    N      0
# 145283    2016     131   1451      62   1285      59    N      0
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %%
#pip install openpyxl
# !pip install xlrd
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl
# ...

# %%
df.to_excel("test.xlsx")

# %%
dir(pd) #od read
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'NamedAgg',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
dir(df) #od to
# Out:
# ['Daynum',
#  'Lscore',
#  'Lteam',
#  'Numot',
#  'Season',
#  'T',
#  'Wloc',
#  'Wscore',
#  'Wteam',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
slownik = {'seria1': [1,10,1,10], 'cecha2': [1,11,111,111]}

# %%
pd.DataFrame(slownik)
# Out:
#    seria1  cecha2
# 0       1       1
# 1      10      11
# 2       1     111
# 3      10     111

# %%
df.shape
# Out:
# (145289, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=145289, step=1)

# %%
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %%
df.describe()
# Out:
#               Season         Daynum          Wteam         Wscore  \
# count  145289.000000  145289.000000  145289.000000  145289.000000
# mean     2001.574834      75.223816    1286.720646      76.600321
# std         9.233342      33.287418     104.570275      12.173033
# min      1985.000000       0.000000    1101.000000      34.000000
# 25%      1994.000000      47.000000    1198.000000      68.000000
# 50%      2002.000000      78.000000    1284.000000      76.000000
# 75%      2010.000000     103.000000    1379.000000      84.000000
# max      2016.000000     132.000000    1464.000000     186.000000
#
#                Lteam         Lscore          Numot
# count  145289.000000  145289.000000  145289.000000
# mean     1282.864064      64.497009       0.044387
# std       104.829234      11.380625       0.247819
# min      1101.000000      20.000000       0.000000
# 25%      1191.000000      57.000000       0.000000
# 50%      1280.000000      64.000000       0.000000
# ...

# %%
df.dtypes
# Out:
# Season     int64
# Daynum     int64
# Wteam      int64
# Wscore     int64
# Lteam      int64
# Lscore     int64
# Wloc      object
# Numot      int64
# dtype: object

# %%
df.max()
# Out:
# Season    2016
# Daynum     132
# Wteam     1464
# Wscore     186
# Lteam     1464
# Lscore     150
# Wloc         N
# Numot        6
# dtype: object

# %% [markdown]
# df.min()

# %%
df.min()
# Out:
# Season    1985
# Daynum       0
# Wteam     1101
# Wscore      34
# Lteam     1101
# Lscore      20
# Wloc         A
# Numot        0
# dtype: object

# %%
df.mean()
# Out:
# Season    2001.574834
# Daynum      75.223816
# Wteam     1286.720646
# Wscore      76.600321
# Lteam     1282.864064
# Lscore      64.497009
# Numot        0.044387
# dtype: float64

# %%
df.Wscore.mean()
# Out:
# 76.60032074004226

# %%
df['Wscore'].max() #zwraca max z kolumny
# Out:
# 186

# %%
df['Wscore'].idxmax()
# Out:
# 24970

# %%
df.Wloc.value_counts() #zliczanie wartosci
# Out:
# H    86471
# A    44229
# N    14589
# Name: Wloc, dtype: int64

# %% [markdown]
# ### Dostęp do danych
#
# Wybieranie wierszy i kolumn

# %%
df['Wloc'][0]
# Out:
# 'N'

# %%
df.loc[0,"Wloc"]
# Out:
# 'N'

# %%
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
df2 = df.loc[:15:3, ['Season', 'Lteam', 'Lscore', 'Numot']]
df2 = df2.reset_index()
df2
# Out:
#    index  Season  Lteam  Lscore  Numot
# 0      0    1985   1328      64      0
# 1      3    1985   1432      54      0
# 2      6    1985   1226      44      0
# 3      9    1985   1424      89      0
# 4     12    1985   1411      72      0
# 5     15    1985   1368      62      0

# %%
df2 = df.iloc[:15:3, [0,2,4,5]]
df2 = df2.reset_index()
df2
# Out:
#    index  Season  Wteam  Lteam  Lscore
# 0      0    1985   1228   1328      64
# 1      3    1985   1165   1432      54
# 2      6    1985   1228   1226      44
# 3      9    1985   1305   1424      89
# 4     12    1985   1374   1411      72

# %%
df.loc[df['Wscore'].idxmax(), 'Lteam']
# Out:
# 1109

# %%
df.sort_values("Lscore")
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 100027    2008      66   1203      49   1387      20    H      0
# 49310     1997      66   1157      61   1204      21    H      0
# 89021     2006      44   1284      41   1343      21    A      0
# 85042     2005      66   1131      73   1216      22    H      0
# 103660    2009      26   1326      59   1359      22    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 77873     2003     110   1383     142   1254     140    H      2
# 24970     1991      68   1258     186   1109     140    H      0
# 22074     1990      96   1261     148   1258     141    H      0
# 16853     1989      68   1258     162   1109     144    A      0
# 17867     1989      92   1258     181   1109     150    H      0
#
# [145289 rows x 8 columns]

# %%
df[(df['Wscore'] > 150) & (df['Lscore'] < 100)]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 12046    1988      40   1328     152   1147      84    H      0
# 12355    1988      52   1328     151   1173      99    N      0
# 25656    1991      84   1106     151   1212      97    H      0
# 28687    1992      54   1261     159   1319      86    H      0
# 35023    1993     112   1380     155   1341      91    A      0
# 52600    1998      33   1395     153   1410      87    H      0

# %% [markdown]
# ### Zadanie
# * Wybierz te wiersze ktore sa sezonow 1988, 89, 90 ktore maja Wlock = N, Lscore < 95 Wscore 155

# %%
(df.Season.isin([1988,1989,1990])) & (df.Wloc == "N") & (df.Lscore < 95) & (df.Wscore > 155)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145284    False
# 145285    False
# 145286    False
# 145287    False
# 145288    False
# Length: 145289, dtype: bool

# %%
v1 = (df.Season.isin([1988,1989,1990]))
v2 = (df.Wloc == "N")
v3 = (df.Lscore < 95)
v4 = (df.Wscore > 145)
df[v1 & v2 & v3 & v4]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 20590    1990      60   1328     147   1317      94    N      0

# %% [markdown]
# ### Grupowanie

# %%
df.Wloc.value_counts()
# Out:
# H    86471
# A    44229
# N    14589
# Name: Wloc, dtype: int64

# %%
df.groupby("Wloc")

# %%
df.groupby(["Wloc", "nowa"])["Wscore"].mean().to
# Out:
# Wloc  nowa
# A     0       74.781343
# H     0       77.739092
# N     0       75.364820
#       1       81.000000
# Name: Wscore, dtype: float64

# %%
df["nowa"] = 0

# %%
df.loc[0:0:3, "nowa"] = 1

# %%
import numpy as np

# %%
df.groupby("Season").agg({"Wscore": np.mean, 'Lteam': max})
# Out:
#            Wscore  Lteam
# Season
# 1985    74.723040   1464
# 1986    74.813640   1464
# 1987    77.993870   1464
# 1988    79.773704   1464
# 1989    81.728511   1464
# 1990    80.846477   1464
# 1991    82.733932   1464
# 1992    79.992004   1464
# 1993    79.508790   1464
# 1994    81.160345   1464
# 1995    80.096149   1464
# 1996    78.205483   1464
# 1997    76.300842   1464
# 1998    77.229902   1464
# 1999    76.043581   1464
# 2000    76.310467   1464
# 2001    77.088650   1464
# 2002    76.963557   1464
# 2003    75.795061   1464
# 2004    74.971122   1464
# 2005    74.693690   1464
# 2006    74.587555   1464
# 2007    74.829467   1464
# 2008    74.962425   1464
# 2009    74.033721   1464
# 2010    74.652480   1464
# 2011    74.374190   1464
# 2012    73.379973   1464
# 2013    72.840789   1464
# 2014    76.101268   1464
# 2015    72.680799   1464
# 2016    78.295958   1464

# %% [markdown]
# ### Pogrupuj po Season i Wloc i zwroc agregacje Wscore = max, Lscore = min, nowa = srednia

# %%
import numpy as np

# %%
df.groupby("Season").agg({
"Wloc": max,
"Lscore":min,
"nowa": np.mean,
    })
# Out:
#        Wloc  Lscore      nowa
# Season
# 1985      N      27  0.000268
# 1986      N      30  0.000000
# 1987      N      25  0.000000
# 1988      N      31  0.000000
# 1989      N      30  0.000000
# 1990      N      28  0.000000
# 1991      N      27  0.000000
# 1992      N      25  0.000000
# 1993      N      27  0.000000
# 1994      N      33  0.000000
# 1995      N      32  0.000000
# 1996      N      28  0.000000
# 1997      N      21  0.000000
# 1998      N      31  0.000000
# 1999      N      27  0.000000
# 2000      N      26  0.000000
# 2001      N      31  0.000000
# 2002      N      23  0.000000
# 2003      N      24  0.000000
# 2004      N      23  0.000000
# 2005      N      22  0.000000
# 2006      N      21  0.000000
# 2007      N      27  0.000000
# 2008      N      20  0.000000
# 2009      N      22  0.000000
# 2010      N      30  0.000000
# 2011      N      30  0.000000
# 2012      N      27  0.000000
# 2013      N      25  0.000000
# ...
